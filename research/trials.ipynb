# %%
# !pip install gdown==5.2.1
# Out:
# Requirement already satisfied: gdown==5.2.1 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from gdown==5.2.1) (4.14.3)
# Requirement already satisfied: filelock in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from gdown==5.2.1) (3.25.2)
# Requirement already satisfied: requests[socks] in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from gdown==5.2.1) (2.32.5)
# Requirement already satisfied: tqdm in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from gdown==5.2.1) (4.67.3)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from beautifulsoup4->gdown==5.2.1) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from beautifulsoup4->gdown==5.2.1) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from requests[socks]->gdown==5.2.1) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from requests[socks]->gdown==5.2.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from requests[socks]->gdown==5.2.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from requests[socks]->gdown==5.2.1) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from requests[socks]->gdown==5.2.1) (1.7.1)
# Requirement already satisfied: colorama in C:\Users\Admin\Downloads\kidney-diseases-classification\kidneyv\Lib\site-packages (from tqdm->gdown==5.2.1) (0.4.6)

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1yLBJ1RQufaHNnr6HUNmx51Rjaupw_g_s/view?usp=drive_link"

# %%
file_id = url.split("/")[-2] 
file_id
# Out:
# '1yLBJ1RQufaHNnr6HUNmx51Rjaupw_g_s'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id=' 
gdown.download(prefix+file_id, "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1yLBJ1RQufaHNnr6HUNmx51Rjaupw_g_s
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1yLBJ1RQufaHNnr6HUNmx51Rjaupw_g_s&confirm=t&uuid=a6e5c0bc-a83f-4054-bdf8-966159151792
# To: c:\Users\Admin\Downloads\kidney-diseases-classification\research\CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip
# 100%|██████████| 1.63G/1.63G [00:31<00:00, 52.4MB/s]
# 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip'
